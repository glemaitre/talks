# %%
from sklearn.datasets import load_breast_cancer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

X, y = load_breast_cancer(return_X_y=True, as_frame=True)
model = make_pipeline(
    StandardScaler(), LogisticRegression()).fit(X, y)
model[-1].coef_
# Out:
# array([[-0.36317072, -0.38770299, -0.35111444, -0.43555896, -0.16176493,
#          0.56259548, -0.85989759, -0.96222175,  0.07616775,  0.32218585,
#         -1.29103479,  0.26892526, -0.65988685, -1.01250087, -0.27717046,
#          0.7362824 ,  0.11052647, -0.3335099 ,  0.29590225,  0.68091528,
#         -1.02936114, -1.31459312, -0.82331706, -1.01059356, -0.67073135,
#          0.04465888, -0.87330064, -0.91195815, -0.88789694, -0.47983137]])

# %%
import pandas as pd

df = pd.Series(model[-1].coef_.ravel(), index=X.columns)
df
# Out:
# mean radius               -0.363171
# mean texture              -0.387703
# mean perimeter            -0.351114
# mean area                 -0.435559
# mean smoothness           -0.161765
# mean compactness           0.562595
# mean concavity            -0.859898
# mean concave points       -0.962222
# mean symmetry              0.076168
# mean fractal dimension     0.322186
# radius error              -1.291035
# texture error              0.268925
# perimeter error           -0.659887
# area error                -1.012501
# smoothness error          -0.277170
# compactness error          0.736282
# concavity error            0.110526
# concave points error      -0.333510
# symmetry error             0.295902
# fractal dimension error    0.680915
# worst radius              -1.029361
# worst texture             -1.314593
# worst perimeter           -0.823317
# worst area                -1.010594
# worst smoothness          -0.670731
# worst compactness          0.044659
# worst concavity           -0.873301
# worst concave points      -0.911958
# worst symmetry            -0.887897
# worst fractal dimension   -0.479831
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context("poster")

# %%
fig, ax = plt.subplots(figsize=(10, 5))
df.plot.bar(ax=ax)
ax.set_ylim([-1, 1])
plt.savefig("../img/coef_breat_cancer.png", bbox_inches="tight")
