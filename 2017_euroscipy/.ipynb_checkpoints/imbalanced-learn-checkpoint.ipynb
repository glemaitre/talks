# %% [markdown]
# # Leverage knowledge from under-represented classes in machine learning: an introduction to `imbalanced-learn`
#
# Guillaume Lemaitre
#
# PyParis 2017

# %%
import numpy as np

# %% [markdown]
# ### Dataset loader

# %%
from imblearn.datasets import fetch_datasets

dataset = fetch_datasets()['satimage']
dataset
# Out:
# {'DESCR': 'satimage',
#  'data': array([[  92.,  115.,  120., ...,  107.,  113.,   87.],
#         [  84.,  102.,  106., ...,   99.,  104.,   79.],
#         [  84.,  102.,  102., ...,   99.,  104.,   79.],
#         ...,
#         [  56.,   68.,   91., ...,   83.,   92.,   74.],
#         [  56.,   68.,   87., ...,   83.,   92.,   70.],
#         [  60.,   71.,   91., ...,   79.,  108.,   92.]]),
#  'target': array([-1, -1, -1, ..., -1, -1, -1])}

# %%
from collections import Counter
Counter(dataset.target)
# Out:
# Counter({-1: 5809, 1: 626})

# %%
X = dataset.data
y = dataset.target

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_vis = pca.fit_transform(X)

# Two subplots, unpack the axes array immediately
f, ax = plt.subplots(figsize=(10, 10))
ax.scatter(X_vis[y == -1, 0], X_vis[y == -1, 1], label="Class -1",
                 alpha=0.5)
ax.scatter(X_vis[y == 1, 0], X_vis[y == 1, 1], label="Class 1",
                 alpha=0.5)
plt.legend()

# %% [markdown]
# ### `fit`, `sample`, and `fit_sample` methods

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE()
X_resampled, y_resampled = smote.fit_sample(X, y)

Counter(y_resampled)
# Out:
# Counter({-1: 5809, 1: 5809})

# %% [markdown]
# ### `Pipeline` in `imbalanced-learn`

# %%
import matplotlib.pyplot as plt
import itertools
# %matplotlib inline

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn.pipeline import make_pipeline as mkp_skl
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegressionCV
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

pipeline_sklearn = mkp_skl(PCA(), LogisticRegressionCV())

pipeline_sklearn.fit(X_train, y_train)
print('Score pipeline:', pipeline_sklearn.score(X_test, y_test))
# Out:
# Score pipeline: 0.903045369795

# %%
from imblearn.pipeline import make_pipeline

pipeline = make_pipeline(SMOTE(kind='borderline1'), PCA(), LogisticRegressionCV())

pipeline.fit(X_train, y_train)
print('Score pipeline:', pipeline.score(X_test, y_test))
# Out:
# Score pipeline: 0.619639527657

# %%
y_pred = pipeline_sklearn.predict(X_test)

print(classification_report_imbalanced(y_test, y_pred))
cm = confusion_matrix(y_pred, y_test)
plot_confusion_matrix(cm, [-1, 1])
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#          -1       0.90      1.00      0.03      0.95      0.85      0.73      1450
#           1       0.80      0.03      1.00      0.05      0.85      0.72       159
#
# avg / total       0.89      0.90      0.12      0.86      0.85      0.73      1609

# %%
y_pred = pipeline.predict(X_test)

print(classification_report_imbalanced(y_test, y_pred))

cm = confusion_matrix(y_pred, y_test)
plot_confusion_matrix(cm, [-1, 1])
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#          -1       0.96      0.60      0.78      0.74      0.41      0.18      1450
#           1       0.18      0.78      0.60      0.29      0.41      0.16       159
#
# avg / total       0.88      0.62      0.76      0.70      0.41      0.18      1609
